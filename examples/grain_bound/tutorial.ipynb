# %%
import numpy as np
import physbo

# %%
def load_data():
    A = np.asarray(np.loadtxt("data/s5-210.csv", skiprows=1, delimiter=","))
    X = A[:, 0:3]
    t = -A[:, 3]
    return X, t

# %%
# Load the data.
# X is the N x d dimensional matrix. Each row of X denotes the d-dimensional feature vector of search candidate.
# t is the N-dimensional vector that represents the corresponding negative energy of search candidates.
# ( It is of course unknown in practice. )
X, t = load_data()

# Normalize the mean and standard deviation along the each column of X to 0 and 1, respectively
X = physbo.misc.centering(X)

# %%
# Declare the class for calling the simulator.
# In this tutorial, we simply refer to the value of t.
# If you want to apply physbo to other problems, you have to customize this class.
class simulator:
    def __init__(self):
        _, self.t = load_data()

    def __call__(self, action):
        return self.t[action]

# %%
# Design of policy

# Declaring the policy by
policy = physbo.search.discrete.policy(test_X=X)
# test_X is the set of candidates which is represented by numpy.array.
# Each row vector represents the feature vector of the corresponding candidate

# set the seed parameter
policy.set_seed(0)

# %%
# If you want to perform the initial random search before starting the Bayesian optimization,
# the random sampling is performed by

res = policy.random_search(max_num_probes=20, simulator=simulator())
# Input:
# max_num_probes: number of random search
# simulator = simulator
# output: physbo.search.discreate.results (class)


# single query Bayesian search
# The single query version of COMBO is performed by
res = policy.bayes_search(
    max_num_probes=80,
    simulator=simulator(),
    score="TS",
    interval=20,
    num_rand_basis=5000,
)

# Input
# max_num_probes: number of searching by Bayesian optimization
# simulator: the class of simulator which is defined above
# score: the type of aquision funciton. TS, EI and PI are available
# interval: the timing for learning the hyper parameter.
#               In this case, the hyper parameter is learned at each 20 steps
#               If you set the negative value to interval, the hyper parameter learning is not performed
#               If you set zero to interval, the hyper parameter learning is performed only at the first step
# num_rand_basis: the number of basis function. If you choose 0,  ordinary Gaussian process runs
# Out:
# 0001-th step: f(x) = -1.070602 (action=15673)
#    current best f(x) = -1.070602 (best action=15673)
#
# 0002-th step: f(x) = -1.153410 (action=16489)
#    current best f(x) = -1.070602 (best action=15673)
#
# 0003-th step: f(x) = -0.981899 (action=7792)
#    current best f(x) = -0.981899 (best action=7792)
#
# 0004-th step: f(x) = -1.066080 (action=13752)
#    current best f(x) = -0.981899 (best action=7792)
#
# 0005-th step: f(x) = -1.043272 (action=9023)
#    current best f(x) = -0.981899 (best action=7792)
#
# 0006-th step: f(x) = -1.125822 (action=1470)
#    current best f(x) = -0.981899 (best action=7792)
#
# 0007-th step: f(x) = -1.070720 (action=14404)
#    current best f(x) = -0.981899 (best action=7792)
#
# 0008-th step: f(x) = -1.091624 (action=14031)
#    current best f(x) = -0.981899 (best action=7792)
#
# 0009-th step: f(x) = -0.963795 (action=5734)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0010-th step: f(x) = -0.989538 (action=3111)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0011-th step: f(x) = -1.135007 (action=1192)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0012-th step: f(x) = -1.003954 (action=8912)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0013-th step: f(x) = -0.994601 (action=1941)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0014-th step: f(x) = -0.971108 (action=4051)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0015-th step: f(x) = -1.096091 (action=14468)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0016-th step: f(x) = -0.982784 (action=8562)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0017-th step: f(x) = -1.052590 (action=16185)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0018-th step: f(x) = -1.079737 (action=17654)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0019-th step: f(x) = -1.025116 (action=4470)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0020-th step: f(x) = -1.048733 (action=1022)
#    current best f(x) = -0.963795 (best action=5734)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -26.92509954754724
# 50 -th epoch marginal likelihood -28.116900149263117
# 100 -th epoch marginal likelihood -28.7170482808381
# 150 -th epoch marginal likelihood -29.03724064450991
# 200 -th epoch marginal likelihood -29.243814308007238
# 250 -th epoch marginal likelihood -29.404990527484884
# 300 -th epoch marginal likelihood -29.543375062782726
# 350 -th epoch marginal likelihood -29.66433788563113
# 400 -th epoch marginal likelihood -29.768631164012973
# 450 -th epoch marginal likelihood -29.85669678455538
# 500 -th epoch marginal likelihood -29.929612908422673
# Done
#
# 0021-th step: f(x) = -1.163543 (action=15502)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0022-th step: f(x) = -1.115291 (action=5468)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0023-th step: f(x) = -1.209434 (action=17785)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0024-th step: f(x) = -1.052777 (action=2744)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0025-th step: f(x) = -1.069404 (action=15133)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0026-th step: f(x) = -1.005694 (action=2996)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0027-th step: f(x) = -1.280940 (action=12010)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0028-th step: f(x) = -1.040693 (action=7092)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0029-th step: f(x) = -0.969117 (action=8879)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0030-th step: f(x) = -1.056882 (action=9663)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0031-th step: f(x) = -0.978277 (action=7732)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0032-th step: f(x) = -0.992851 (action=368)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0033-th step: f(x) = -1.046641 (action=6511)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0034-th step: f(x) = -1.063484 (action=7559)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0035-th step: f(x) = -2.716337 (action=8991)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0036-th step: f(x) = -1.064335 (action=9924)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0037-th step: f(x) = -1.009942 (action=114)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0038-th step: f(x) = -1.132489 (action=15657)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0039-th step: f(x) = -1.052640 (action=11273)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0040-th step: f(x) = -1.029932 (action=8153)
#    current best f(x) = -0.963795 (best action=5734)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 57.27443995742372
# 50 -th epoch marginal likelihood 39.61996417095699
# 100 -th epoch marginal likelihood 28.75843642947389
# 150 -th epoch marginal likelihood 21.904482272567265
# 200 -th epoch marginal likelihood 17.37533326894912
# 250 -th epoch marginal likelihood 14.2779779855206
# 300 -th epoch marginal likelihood 12.105710146208324
# 350 -th epoch marginal likelihood 10.550790094511335
# 400 -th epoch marginal likelihood 9.41741995795864
# 450 -th epoch marginal likelihood 8.576755872035882
# 500 -th epoch marginal likelihood 7.941737514349171
# Done
#
# 0041-th step: f(x) = -0.986440 (action=6997)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0042-th step: f(x) = -0.991094 (action=3048)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0043-th step: f(x) = -1.146469 (action=28)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0044-th step: f(x) = -1.474650 (action=14994)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0045-th step: f(x) = -1.040936 (action=6486)
#    current best f(x) = -0.963795 (best action=5734)
#
# 0046-th step: f(x) = -0.957557 (action=8658)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0047-th step: f(x) = -0.990559 (action=1554)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0048-th step: f(x) = -1.112963 (action=16435)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0049-th step: f(x) = -0.996640 (action=2980)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0050-th step: f(x) = -0.983457 (action=11972)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0051-th step: f(x) = -2.497145 (action=17981)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0052-th step: f(x) = -1.046715 (action=17963)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0053-th step: f(x) = -1.034998 (action=8965)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0054-th step: f(x) = -1.121553 (action=3543)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0055-th step: f(x) = -0.970354 (action=5071)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0056-th step: f(x) = -1.000414 (action=13504)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0057-th step: f(x) = -1.105581 (action=3450)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0058-th step: f(x) = -1.157715 (action=17034)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0059-th step: f(x) = -1.195993 (action=6014)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0060-th step: f(x) = -1.008763 (action=13357)
#    current best f(x) = -0.957557 (best action=8658)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 95.64584307596252
# 50 -th epoch marginal likelihood 66.35048123357063
# 100 -th epoch marginal likelihood 47.31866223555388
# 150 -th epoch marginal likelihood 34.99052624000419
# 200 -th epoch marginal likelihood 26.852103068210674
# 250 -th epoch marginal likelihood 21.378391902446452
# 300 -th epoch marginal likelihood 17.634634928059192
# 350 -th epoch marginal likelihood 15.037465120793513
# 400 -th epoch marginal likelihood 13.214200445071874
# 450 -th epoch marginal likelihood 11.92081527956428
# 500 -th epoch marginal likelihood 10.994026735196492
# Done
#
# 0061-th step: f(x) = -1.042869 (action=10245)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0062-th step: f(x) = -1.091613 (action=5966)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0063-th step: f(x) = -1.152803 (action=1859)
#    current best f(x) = -0.957557 (best action=8658)
# 0064-th step: f(x) = -0.997708 (action=3033)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0065-th step: f(x) = -1.071346 (action=12024)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0066-th step: f(x) = -0.996107 (action=4218)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0067-th step: f(x) = -0.996148 (action=4254)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0068-th step: f(x) = -2.497328 (action=17945)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0069-th step: f(x) = -1.144047 (action=13010)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0070-th step: f(x) = -1.051960 (action=17059)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0071-th step: f(x) = -1.181294 (action=17398)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0072-th step: f(x) = -0.994355 (action=2886)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0073-th step: f(x) = -0.968925 (action=4681)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0074-th step: f(x) = -0.972985 (action=11027)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0075-th step: f(x) = -0.963759 (action=5698)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0076-th step: f(x) = -0.964398 (action=5975)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0077-th step: f(x) = -1.018063 (action=2974)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0078-th step: f(x) = -0.992400 (action=740)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0079-th step: f(x) = -1.020451 (action=5989)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0080-th step: f(x) = -1.074223 (action=2804)
#    current best f(x) = -0.957557 (best action=8658)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 171.03306059563727
# 50 -th epoch marginal likelihood 127.11391202528407
# 100 -th epoch marginal likelihood 97.86972980514525
# 150 -th epoch marginal likelihood 76.72198878519796
# 200 -th epoch marginal likelihood 63.66870436920041
# 250 -th epoch marginal likelihood 54.3007049773918
# 300 -th epoch marginal likelihood 45.57502605325236
# 350 -th epoch marginal likelihood 39.54814143645811
# 400 -th epoch marginal likelihood 35.48162280619671
# 450 -th epoch marginal likelihood 32.44895962894607
# 500 -th epoch marginal likelihood 30.243937817044753
# Done
#
# 0081-th step: f(x) = -1.062190 (action=15725)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0082-th step: f(x) = -1.008143 (action=6030)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0083-th step: f(x) = -0.997863 (action=2536)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0084-th step: f(x) = -1.013053 (action=36)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0085-th step: f(x) = -1.052591 (action=8980)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0086-th step: f(x) = -1.052411 (action=14960)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0087-th step: f(x) = -0.972223 (action=11135)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0088-th step: f(x) = -1.011104 (action=11359)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0089-th step: f(x) = -0.995949 (action=2294)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0090-th step: f(x) = -1.013012 (action=0)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0091-th step: f(x) = -1.035765 (action=4537)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0092-th step: f(x) = -0.968059 (action=8287)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0093-th step: f(x) = -1.136152 (action=16238)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0094-th step: f(x) = -1.554029 (action=15014)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0095-th step: f(x) = -1.009086 (action=13949)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0096-th step: f(x) = -0.964418 (action=5068)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0097-th step: f(x) = -0.992852 (action=7807)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0098-th step: f(x) = -1.276674 (action=6006)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0099-th step: f(x) = -1.053327 (action=11364)
#    current best f(x) = -0.957557 (best action=8658)
#
# 0100-th step: f(x) = -1.014598 (action=12764)
#    current best f(x) = -0.957557 (best action=8658)

# %%
# The result of searching is summarized in the class physbo.search.discrete.results.history()
# res.fx: observed negative energy at each step
# res.chosen_actions: history of choosed actions
# fbest, best_action= res.export_all_sequence_best_fx(): current best fx and current best action
#                                                                                                   that has been observed until each step
# res.total_num_search: total number of search
print("f(x)=", res.fx[0 : res.total_num_search])
best_fx, best_action = res.export_all_sequence_best_fx()
print("current best", best_fx)
print("current best action=", best_action)
print("history of chosen actions=", res.chosen_actions[0 : res.total_num_search])
# Out:
# f(x)= [-1.07060214 -1.15340978 -0.98189856 -1.0660804  -1.04327156 -1.12582192
#  -1.07071983 -1.09162401 -0.96379539 -0.98953771 -1.13500669 -1.00395435
#  -0.99460129 -0.97110762 -1.09609145 -0.98278381 -1.05258966 -1.07973688
#  -1.02511608 -1.04873284 -1.16354262 -1.1152908  -1.20943435 -1.05277671
#  -1.06940391 -1.00569357 -1.2809399  -1.04069258 -0.96911653 -1.05688198
#  -0.97827713 -0.99285126 -1.04664055 -1.06348437 -2.71633654 -1.06433493
#  -1.00994212 -1.13248855 -1.05263969 -1.02993177 -0.98644049 -0.99109357
#  -1.14646882 -1.47465017 -1.04093649 -0.95755746 -0.99055856 -1.11296313
#  -0.99663985 -0.98345726 -2.4971452  -1.04671475 -1.03499762 -1.12155347
#  -0.97035371 -1.00041394 -1.10558125 -1.15771547 -1.19599307 -1.0087635
#  -1.0428693  -1.09161349 -1.15280256 -0.99770846 -1.07134639 -0.9961074
#  -0.99614833 -2.49732771 -1.14404676 -1.05195998 -1.18129385 -0.99435453
#  -0.96892464 -0.97298528 -0.96375929 -0.96439778 -1.0180634  -0.99239983
#  -1.02045078 -1.07422272 -1.06219033 -1.00814263 -0.99786253 -1.0130527
#  -1.05259136 -1.05241056 -0.97222313 -1.01110425 -0.99594877 -1.01301176
#  -1.03576489 -0.96805929 -1.13615205 -1.55402855 -1.00908644 -0.96441796
#  -0.9928524  -1.27667372 -1.05332708 -1.01459832]
# current best [-1.07060214 -1.07060214 -0.98189856 -0.98189856 -0.98189856 -0.98189856
#  -0.98189856 -0.98189856 -0.96379539 -0.96379539 -0.96379539 -0.96379539
#  -0.96379539 -0.96379539 -0.96379539 -0.96379539 -0.96379539 -0.96379539
#  -0.96379539 -0.96379539 -0.96379539 -0.96379539 -0.96379539 -0.96379539
#  -0.96379539 -0.96379539 -0.96379539 -0.96379539 -0.96379539 -0.96379539
#  -0.96379539 -0.96379539 -0.96379539 -0.96379539 -0.96379539 -0.96379539
#  -0.96379539 -0.96379539 -0.96379539 -0.96379539 -0.96379539 -0.96379539
#  -0.96379539 -0.96379539 -0.96379539 -0.95755746 -0.95755746 -0.95755746
#  -0.95755746 -0.95755746 -0.95755746 -0.95755746 -0.95755746 -0.95755746
#  -0.95755746 -0.95755746 -0.95755746 -0.95755746 -0.95755746 -0.95755746
#  -0.95755746 -0.95755746 -0.95755746 -0.95755746 -0.95755746 -0.95755746
#  -0.95755746 -0.95755746 -0.95755746 -0.95755746 -0.95755746 -0.95755746
#  -0.95755746 -0.95755746 -0.95755746 -0.95755746 -0.95755746 -0.95755746
#  -0.95755746 -0.95755746 -0.95755746 -0.95755746 -0.95755746 -0.95755746
#  -0.95755746 -0.95755746 -0.95755746 -0.95755746 -0.95755746 -0.95755746
#  -0.95755746 -0.95755746 -0.95755746 -0.95755746 -0.95755746 -0.95755746
#  -0.95755746 -0.95755746 -0.95755746 -0.95755746]
# current best action= [15673. 15673.  7792.  7792.  7792.  7792.  7792.  7792.  5734.  5734.
#   5734.  5734.  5734.  5734.  5734.  5734.  5734.  5734.  5734.  5734.
#   5734.  5734.  5734.  5734.  5734.  5734.  5734.  5734.  5734.  5734.
#   5734.  5734.  5734.  5734.  5734.  5734.  5734.  5734.  5734.  5734.
#   5734.  5734.  5734.  5734.  5734.  8658.  8658.  8658.  8658.  8658.
#   8658.  8658.  8658.  8658.  8658.  8658.  8658.  8658.  8658.  8658.
#   8658.  8658.  8658.  8658.  8658.  8658.  8658.  8658.  8658.  8658.
#   8658.  8658.  8658.  8658.  8658.  8658.  8658.  8658.  8658.  8658.
#   8658.  8658.  8658.  8658.  8658.  8658.  8658.  8658.  8658.  8658.
#   8658.  8658.  8658.  8658.  8658.  8658.  8658.  8658.  8658.  8658.]
# history of chosen actions= [15673 16489  7792 13752  9023  1470 14404 14031  5734  3111  1192  8912
#   1941  4051 14468  8562 16185 17654  4470  1022 15502  5468 17785  2744
#  15133  2996 12010  7092  8879  9663  7732   368  6511  7559  8991  9924
#    114 15657 11273  8153  6997  3048    28 14994  6486  8658  1554 16435
#   2980 11972 17981 17963  8965  3543  5071 13504  3450 17034  6014 13357
#  10245  5966  1859  3033 12024  4218  4254 17945 13010 17059 17398  2886
#   4681 11027  5698  5975  2974   740  5989  2804 15725  6030  2536    36
#   8980 14960 11135 11359  2294     0  4537  8287 16238 15014 13949  5068
#   7807  6006 11364 12764]

# %%
# save the results
res.save("test.npz")

# %%
del res

# %%
# load the results
res = physbo.search.discrete.results.history()
res.load("test.npz")
